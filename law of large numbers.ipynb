# %% [markdown]
# ![law%20of%20large%20numbers.PNG](attachment:law%20of%20large%20numbers.PNG)

# %%
# randn() function--> returns= A random numbers from a normally distributed set of numbers.

# %%
#"if"statement--> isolates the block of code and execute it only when a certain condition is met.

# %%
import numpy as np
from numpy.random import randn
N=1000
counter=0
for i in randn(N):
   if i >-1 and i<1:
      counter =counter+1
counter/N
# Out:
# 0.709
